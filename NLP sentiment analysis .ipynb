# %%
import numpy as np
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('Downloads/Data Analyst - Test Data - US.csv', encoding = 'utf-8')
data.head(5)
# Out:
#                                               Review        date     Location
# 0  I was very impressed with the resort.\n Great ...  2019/08/20    Sebastian
# 1  The rooms were nice the outside needs work als...  2019/08/20  Los Angeles
# 2  Great location! I have stayed at this hotel on...  2019/08/20      Georgia
# 3  The hotel was adequate for my stay. The strips...  2019/08/20          NaN
# 4  Great location, room was large and spacious. P...  2019/08/19  Palm Harbor

# %%
pip install spacy-transformers==0.6.0
# Out:
# ...
#      ---------------------------------------- 60.2/60.2 kB 1.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 6.1/6.1 MB 2.7 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   pip subprocess to install build dependencies did not run successfully.
#   exit code: 1
#
#   [303 lines of output]
# ...
#     Using cached setuptools-63.1.0-py3-none-any.whl (1.2 MB)
# ...
#     Using cached wheel-0.37.1-py2.py3-none-any.whl (35 kB)
# ...
#        -------------------------------------- 985.1/985.1 kB 2.2 MB/s eta 0:00:00
# ...
#        -------------------------------------- 112.4/112.4 kB 3.2 MB/s eta 0:00:00
# ...
#        ---------------------------------------- 1.3/1.3 MB 2.0 MB/s eta 0:00:00
# ...

# %%
data.describe()
# Out:
#                                        Review      date  \
# count                                    6393      6448
# unique                                   6384       403
# top     Amazing\n  \n  Read more\n  Read less  Jun 2019
# freq                                        4       145
#
#                         Location
# count                       1711
# unique                      1082
# top     United States of America
# freq                         116

# %%
data.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6448 entries, 0 to 6447
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Review    6393 non-null   object
#  1   date      6448 non-null   object
#  2   Location  1711 non-null   object
# dtypes: object(3)
# memory usage: 3.0 MB

# %%
sns.countplot('Location', data=data)
# Out:
# C:\Users\msi1\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Location', ylabel='count'>
# C:\Users\msi1\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 26481 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\msi1\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 20140 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\msi1\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 22823 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
data['Location'].unique().shape
# Out:
# (1083,)

# %%
sns.heatmap(data.isnull(),yticklabels=False, cbar=False, cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
# In location around 90 percent data is null

# %%
data['date']=pd.to_datetime(data['date'])

# %%
data
# Out:
#                                                  Review       date  \
# 0     I was very impressed with the resort.\n Great ... 2019-08-20
# 1     The rooms were nice the outside needs work als... 2019-08-20
# 2     Great location! I have stayed at this hotel on... 2019-08-20
# 3     The hotel was adequate for my stay. The strips... 2019-08-20
# 4     Great location, room was large and spacious. P... 2019-08-19
# ...                                                 ...        ...
# 6443  ·the staff were all so friendly. frank, the ch... 2019-07-12
# 6444         ·the internet barely worked or didn't work 2019-07-12
# 6445  ·the location was great.\n \n \n \n \n ·the be... 2019-07-10
# 6446  ·we were early for check in and the staff was ... 2019-07-10
# 6447  ·staff, free coffee, location and activities.\... 2019-07-10
#
#                       Location
# 0                    Sebastian
# 1                  Los Angeles
# 2                      Georgia
# 3                          NaN
# ...

# %%
data['date'].max()
# Out:
# Timestamp('2019-08-20 00:00:00')

# %%
data.loc[data['Location']== 'United States of America']
# Out:
#                                                  Review       date  \
# 6267  ·it was so close to what we were there for!\n ... 2019-08-19
# 6271  ·the location was excellent to td garden, as w... 2019-08-18
# 6272  ·there is nothing to complain about the locati... 2019-08-18
# 6273  ·the location \n \n \n \n \n ·the pricing, the... 2019-08-18
# 6274  ·the parking for the price you pay and no park... 2019-08-18
# ...                                                 ...        ...
# 6443  ·the staff were all so friendly. frank, the ch... 2019-07-12
# 6444         ·the internet barely worked or didn't work 2019-07-12
# 6445  ·the location was great.\n \n \n \n \n ·the be... 2019-07-10
# 6446  ·we were early for check in and the staff was ... 2019-07-10
# 6447  ·staff, free coffee, location and activities.\... 2019-07-10
#
#                       Location
# 6267  United States of America
# 6271  United States of America
# 6272  United States of America
# 6273  United States of America
# ...

# %%
k=data.groupby('date').mean()
k
# Out:
# C:\Users\msi1\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Empty DataFrame
# Columns: []
# ...

# %% [markdown]
# k.mean()

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %% [markdown]
# Below, we have applied a function called SentimentIntensityAnalyzer() from the nltk.sentiment.vader package. The SentimentAnalyzer can implement and facilitate sentiment analysis tasks with NLTK algorithms and features, so the sentiment scores can be generated without complex coding. Before we use it, we need to call it.

# %%
sia= SentimentIntensityAnalyzer()

# %%
reviews= data 
df=data

# %%
df.drop(axis=1,columns=['date','Location'],inplace=True)
df
# Out:
#                                                  Review
# 0     I was very impressed with the resort.\n Great ...
# 1     The rooms were nice the outside needs work als...
# 2     Great location! I have stayed at this hotel on...
# 3     The hotel was adequate for my stay. The strips...
# 4     Great location, room was large and spacious. P...
# ...                                                 ...
# 6443  ·the staff were all so friendly. frank, the ch...
# 6444         ·the internet barely worked or didn't work
# 6445  ·the location was great.\n \n \n \n \n ·the be...
# 6446  ·we were early for check in and the staff was ...
# 6447  ·staff, free coffee, location and activities.\...
#
# [6448 rows x 1 columns]

# %%
pip install langdetect
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install google_trans_new
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import googletrans 
from googletrans import *
translator = googletrans.translator()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5580/545200420.py in <module>
#       1 import googletrans
#       2 from googletrans import *
# ----> 3 translator = googletrans.translator()
#       4
#
# AttributeError: module 'googletrans' has no attribute 'translator'

# %%
df['translated_value'] = df['Review'].apply(translator.translate, src='auto', dest='en').apply(getattr, args=('text',))
